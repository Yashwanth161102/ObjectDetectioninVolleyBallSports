# %%
import zipfile
import requests
import cv2
import matplotlib.pyplot as plt
import glob 
import random
import os

# %%
def yolo2bbox(bboxes):
    xmin, ymin = bboxes[0]-bboxes[2]/2, bboxes[1]-bboxes[3]/2
    xmax, ymax = bboxes[0]+bboxes[2]/2, bboxes[1]+bboxes[3]/2
    return xmin, ymin, xmax, ymax

# %%
def plot_box(image, bboxes, labels):
    # Need the image height and width to denormalize
    # the bounding box coordinates
    h, w, _ = image.shape
    for box_num, box in enumerate(bboxes):
        x1, y1, x2, y2 = yolo2bbox(box)
        # Denormalize the coordinates.
        xmin = int(x1*w)
        ymin = int(y1*h)
        xmax = int(x2*w)
        ymax = int(y2*h)

        thickness = max(2, int(w/275))
                
        cv2.rectangle(
            image, 
            (xmin, ymin), (xmax, ymax),
            color=(0, 0, 255),
            thickness=thickness
        )
    return image

# %%
def plot(image_paths, label_paths, num_samples):
    all_images = []
    all_images.extend(glob.glob(image_paths+'/*.jpg'))
    all_images.extend(glob.glob(image_paths+'/*.JPG'))
    
    all_images.sort()
    num_images = len(all_images)

    plt.figure(figsize=(15, 12))
    for i in range(num_samples):
        j = random.randint(0,num_images-1)
        image_name = all_images[j]
        image_name = '.'.join(image_name.split(os.path.sep)[-1].split('.')[:-1])
        image = cv2.imread(all_images[j])
        with open(os.path.join(label_paths, image_name+'.txt'), 'r') as f:
            bboxes = []
            labels = []
            label_lines = f.readlines()
            for label_line in label_lines:
                label = label_line[0]
                bbox_string = label_line[2:]
                x_c, y_c, w, h = bbox_string.split(' ')
                x_c = float(x_c)
                y_c = float(y_c)
                w = float(w)
                h = float(h)
                bboxes.append([x_c, y_c, w, h])
                labels.append(label)
        result_image = plot_box(image, bboxes, labels)
        plt.subplot(2, 2, i+1)
        plt.imshow(result_image[:, :, ::-1])
        plt.axis('off')
    plt.subplots_adjust(wspace=1)
    plt.tight_layout()
    plt.show()

# %%
plot(
    image_paths='train/images/', 
    label_paths='train/labels/',
    num_samples=4,
)

# %%
EPOCHS = 50
# !yolo task=detect mode=train model=yolov8n.pt imgsz=640 data=data.yaml epochs={EPOCHS} batch=8 name=yolov8n_v8_50e
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:01<00:00, 3.90MB/s]
# New https://pypi.org/project/ultralytics/8.1.22 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.9.10 torch-2.2.0 CPU (Apple M1)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=data.yaml, epochs=50, patience=50, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=yolov8n_v8_50e, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8n_v8_50e
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/yolov8n_v8_50e', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /Users/yashwanthponugoti/Documents/Players-Dataset-2/train/label
# train: New cache created: /Users/yashwanthponugoti/Documents/Players-Dataset-2/train/labels.cache
# val: Scanning /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/labels.
# val: New cache created: /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/labels.cache
# Plotting labels to runs/detect/yolov8n_v8_50e/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/yolov8n_v8_50e
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      2.167      2.396      1.827         88        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         60        
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         60        555      0.788      0.755      0.755      0.242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G      1.449     0.8882      1.386         65        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         60        555      0.826      0.802      0.812      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G      1.451     0.8877      1.377         63        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         60        555      0.808      0.778      0.789      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G      1.434     0.8695      1.375         71        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         60        555      0.765      0.741      0.734      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G      1.416     0.8656      1.354         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         60        555      0.821      0.787      0.805      0.282
#
# 50 epochs completed in 1.128 hours.
# Optimizer stripped from runs/detect/yolov8n_v8_50e/weights/last.pt, 6.3MB
# Optimizer stripped from runs/detect/yolov8n_v8_50e/weights/best.pt, 6.2MB
#
# Validating runs/detect/yolov8n_v8_50e/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.9.10 torch-2.2.0 CPU (Apple M1)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         60        555      0.822      0.831       0.85      0.367
# Speed: 1.8ms preprocess, 197.2ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/yolov8n_v8_50e
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo task=detect \
mode=predict \
model=runs/detect/yolov8n_v8_50e/weights/best.pt \
source=valid/images \
imgsz=640 \
name=yolov8n_v8_50e_infer640 \
show_labels=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.9.10 torch-2.2.0 CPU (Apple M1)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-1-_png.rf.842aa76312bebffd49cb66b65a426cb4.jpg: 640x640 16 players, 93.6ms
# image 2/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-10-_png.rf.8e9740f8180e14cac0080d87c44825e7.jpg: 640x640 14 players, 88.4ms
# image 3/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-102-_png.rf.f06a08569df1b381719707ccd3a2876c.jpg: 640x640 1 player, 88.9ms
# image 4/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-11-_png.rf.bbe441961660d78fee6ab926c081d915.jpg: 640x640 19 players, 81.3ms
# image 5/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-114-_png.rf.d11647bcae05fb83c352a4eaa2fe298e.jpg: 640x640 14 players, 85.0ms
# image 6/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-116-_png.rf.48d957e044baa01d6f47ac754114eef6.jpg: 640x640 13 players, 79.2ms
# image 7/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-12-_png.rf.fa7c3d06f8ff64ae797a9aeb124eca29.jpg: 640x640 9 players, 73.0ms
# image 8/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-128-_png.rf.f94fb35f6c40f49a45a86c63e879b320.jpg: 640x640 12 players, 71.6ms
# image 9/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-13-_png.rf.07256400c0ded85a6610129fed9f310e.jpg: 640x640 13 players, 71.6ms
# image 10/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-130-_png.rf.25a7960b32d99eacbfee4d348c80bf31.jpg: 640x640 15 players, 71.3ms
# image 11/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-131-_png.rf.feb9cd7faff037c9dd67ca385fdc4cbd.jpg: 640x640 18 players, 73.1ms
# image 12/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-14-_png.rf.74eda59c2d0fc43c8046f81638d1f150.jpg: 640x640 11 players, 76.8ms
# image 13/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-145-_png.rf.9b569cee6d723890022e7c16568d6e30.jpg: 640x640 19 players, 85.0ms
# image 14/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-157-_png.rf.8e4c2e435062af514467b00b0f625338.jpg: 640x640 15 players, 83.9ms
# image 15/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-158-_png.rf.e79f815ef99f964ae087ead538632e1e.jpg: 640x640 19 players, 86.6ms
# image 16/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-16-_png.rf.0648f4deeee402d367f7c0b46307dbc6.jpg: 640x640 12 players, 88.1ms
# image 17/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-169-_png.rf.9193cacc64fa6adb3d24a79b18a8412e.jpg: 640x640 15 players, 89.8ms
# image 18/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley
60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-41-_png.rf.99cf5f5c0bc6ca54f0a0cd4de52ab5d6.jpg: 640x640 17 players, 72.4ms
# image 43/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-43-_png.rf.e097a7c83f06c81f301dec495bbdb98c.jpg: 640x640 14 players, 74.8ms
# image 44/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-44-_png.rf.f57aca54adf23bf4891a92bf902d45ba.jpg: 640x640 17 players, 72.2ms
# image 45/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-45-_png.rf.77d88baa23269e30cff78d403bb85231.jpg: 640x640 14 players, 73.1ms
# image 46/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-46-_png.rf.9e4b3f22c0ce288bb46d0d3725e2d004.jpg: 640x640 19 players, 74.7ms
# image 47/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-47-_png.rf.ab53626cea84bed8de0ffe629641d16b.jpg: 640x640 17 players, 85.2ms
# image 48/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-48-_png.rf.d2de59c521b9743763107f99395d5f4c.jpg: 640x640 15 players, 74.3ms
# image 49/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-50-_png.rf.5fe2c5c2847aed7afb083c6f7e80197d.jpg: 640x640 14 players, 76.8ms
# image 50/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-52-_png.rf.c82932281f71df946ba8a0272a067160.jpg: 640x640 22 players, 72.4ms
# image 51/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-59-_png.rf.ec36fe3326d7c7595d0007c932055f81.jpg: 640x640 14 players, 74.2ms
# image 52/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-6-_png.rf.6093db61e50b0139a944e2009d3229f1.jpg: 640x640 11 players, 72.9ms
# image 53/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-68-_png.rf.e2377085f8a394e2b16290722e7089c9.jpg: 640x640 14 players, 74.6ms
# image 54/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-7-_png.rf.90fbd0d135a0a0226da6b628a3a9d02a.jpg: 640x640 11 players, 77.0ms
# image 55/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-72-_png.rf.f685938106cf2817118ca09ff04c657c.jpg: 640x640 15 players, 76.7ms
# image 56/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-8-_png.rf.62335485130f78e112167cbd833cc43f.jpg: 640x640 14 players, 79.7ms
# image 57/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-89-_png.rf.a4c983498248608bcab9169f4d817653.jpg: 640x640 19 players, 92.9ms
# image 58/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-9-_png.rf.44f9ee1536e9ae9ed9b009d02a3742bd.jpg: 640x640 15 players, 81.2ms
# image 59/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-90-_png.rf.4ee163679e96cfd7140043c1b661df2f.jpg: 640x640 14 players, 74.1ms
# image 60/60 /Users/yashwanthponugoti/Documents/Players-Dataset-2/valid/images/volley-95-_png.rf.e5eafad5364f8e5cc21a68213abd0d03.jpg: 640x640 9 players, 75.0ms
# Speed: 1.0ms preprocess, 78.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/yolov8n_v8_50e_infer640
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Plot and visualize images in a 2x2 grid.
def visualize(result_dir, num_samples=4):
    """
    Function accepts a list of images and plots
    them in a 2x2 grid.
    """
    plt.figure(figsize=(20, 12))
    image_names = glob.glob(os.path.join(result_dir, '*.jpg'))
    random.shuffle(image_names)
    for i, image_name in enumerate(image_names):
        image = plt.imread(image_name)
        plt.subplot(2, 2, i+1)
        plt.imshow(image)
        plt.axis('off')
        if i == num_samples-1:
            break
    plt.tight_layout()
    plt.show()

# %%
visualize('runs/detect/yolov8n_v8_50e_infer640/')
